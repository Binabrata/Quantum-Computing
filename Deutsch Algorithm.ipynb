# %% [markdown]
# <a href="https://colab.research.google.com/github/Binabrata/Quantum-Computing/blob/main/Deutsch-Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# !pip install qiskit-aer
# !pip install pylatexenc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 40.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 41.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=322c7024072612da0e8e74fb812c42d42f91a139c320dbd0c79eec6bc6a7f91f
#   Stored in directory: /root/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# ...

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
from qiskit.circuit.library import IGate

# %% [markdown]
# ## Constant Oracle - with Identity Gate

# %%
# Implement Deutsch Algorithm for a Constant Function
qc = QuantumCircuit(2, 1, name="qc")

# Place the second qubit in state |1>
qc.x(1)
qc.barrier()

# Place each qubit in Superposition
qc.h(0)
qc.h(1)
qc.barrier()

# Creating a constant oracle
qc.id(0)
qc.id(1)
qc.barrier()

# Putting a Hadamard to the first qubit
qc.h(0)
qc.barrier()

# Measuring the first qubit
qc.measure(0,0)

qc.draw('mpl')

# %%
# Test the Constant Oracle

from qiskit import transpile

backend = Aer.get_backend('qasm_simulator')
compiled_circuit = transpile(qc, backend)

# Grab results from the job
result = backend.run(compiled_circuit).result()

# Returns counts
counts = result.get_counts(compiled_circuit)
print("\nTotal counts are:",counts)

# Plot a histogram
plot_histogram(counts)
# Out:
# Total counts are: {'0': 1024}

# %% [markdown]
# ## Constant Oracle - with X Gate applied on the second qubit

# %%
# Implement Deutsch Algorithm for a Constant Function
qc = QuantumCircuit(2, 1, name="qc")

# Place the second qubit in state |1>
qc.x(1)
qc.barrier()

# Place each qubit in Superposition
qc.h(0)
qc.h(1)
qc.barrier()

# Creating a constant oracle
qc.id(0)
qc.x(1)
qc.barrier()

# Putting a Hadamard to the first qubit
qc.h(0)
qc.barrier()

# Measuring the first qubit
qc.measure(0,0)

qc.draw('mpl')

# %%
# Test the Constant Oracle

from qiskit import transpile

backend = Aer.get_backend('qasm_simulator')
compiled_circuit = transpile(qc, backend)

# Grab results from the job
result = backend.run(compiled_circuit).result()

# Returns counts
counts = result.get_counts(compiled_circuit)
print("\nTotal counts are:",counts)

# Plot a histogram
plot_histogram(counts)
# Out:
# Total counts are: {'0': 1024}

# %% [markdown]
# ## Balanced Oracles - with CX Gate

# %%
# Implement Deutsch Algorithm for a Balanced Function
qc = QuantumCircuit(2, 1, name="qc")

# Place the second qubit in state |1>
qc.x(1)
qc.barrier()

# Place each qubit in Superposition
qc.h(0)
qc.h(1)
qc.barrier()

# Creating a balanced oracle
qc.cx(0,1)
qc.barrier()

# Putting a Hadamard to the first qubit
qc.h(0)
qc.barrier()

# Measuring the first qubit
qc.measure(0,0)

qc.draw('mpl')

# %%
# Test the Balanced Oracle

from qiskit import transpile

backend = Aer.get_backend('qasm_simulator')
compiled_circuit = transpile(qc, backend)

# Grab results from the job
result = backend.run(compiled_circuit).result()

# Returns counts
counts = result.get_counts(compiled_circuit)
print("\nTotal counts are:",counts)

# Plot a histogram
plot_histogram(counts)
# Out:
# Total counts are: {'1': 1024}

# %% [markdown]
# ## Balanced Oracles - with CX Gate with X Gate

# %%
# Implement Deutsch Algorithm for a Balanced Function
qc = QuantumCircuit(2, 1, name="qc")

# Place the second qubit in state |1>
qc.x(1)
qc.barrier()

# Place each qubit in Superposition
qc.h(0)
qc.h(1)
qc.barrier()

# Creating a balanced oracle
qc.cx(0,1)
qc.x(1)
qc.barrier()

# Putting a Hadamard to the first qubit
qc.h(0)
qc.barrier()

# Measuring the first qubit
qc.measure(0,0)

qc.draw('mpl')

# %%
# Test the Balanced Oracle

from qiskit import transpile

backend = Aer.get_backend('qasm_simulator')
compiled_circuit = transpile(qc, backend)

# Grab results from the job
result = backend.run(compiled_circuit).result()

# Returns counts
counts = result.get_counts(compiled_circuit)
print("\nTotal counts are:",counts)

# Plot a histogram
plot_histogram(counts)
# Out:
# Total counts are: {'1': 1024}
